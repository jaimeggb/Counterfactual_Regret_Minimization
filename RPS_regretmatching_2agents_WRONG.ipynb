# %%
 import random

# %%
##Returns the adjusted strategy after an iteration
def getStrategy(regretSum,strategySum):
    ''' 
    Define each variable and give example values:
    - regretSum = [-2, -5, 2] ---> cumulative regret
    - strategy = [0.3333333333333333, 0.3333333333333333, 0.3333333333333333] or [0.0, 0.0, 1.0] or [0.3, 0.4, 0.3] ---> policy yielded by regret matching for next RPS showdown
    - strategySum = [1.0, 0.3333333333333333, 3.6666666666666665] ---> sum of probabilities in strategy array over all iterations
    - normalizingSum = 37 ---> used to get strategy array probabilities ---> strategy[i] = strategy[i]/normalizingSum ---> sum of positive regrets only
    '''
    actions = 3
    normalizingSum = 0
    strategy = [0,0,0]
    #Normalizingsum is the sum of positive regrets. 
    #This ensures do not 'over-adjust' and converge to equilibrium
    for i in range(0,actions):
        if regretSum[i] > 0:
            strategy[i] = regretSum[i]
        else:
            strategy[i] = 0
        normalizingSum += strategy[i]
    ##This loop normalizes our updated strategy
    for i in range(0,actions):
        if normalizingSum > 0:
            strategy[i] = strategy[i]/normalizingSum
        else:
            #Default to 33%
            strategy[i] = 1.0 / actions
        strategySum[i] += strategy[i]
    return (strategy, strategySum)

# %%
#Returns a random action according to the strategy
def getAction(strategy):
    ''' 
    As an example, use strategy = [0.3, 0.4, 0.3]
    This function returns 'ROCK' (0) if a random uniform generated value falls between 0-0.3
    This function returns 'PAPER' (2) if a random uniform generated value falls between 0.3-0.7 
    This function returns 'SCISSORS' (2) if a random uniform generated value falls between 0.7-1 
    '''
    r = random.uniform(0,1)
    if r >= 0 and r < strategy[0]:
        return 0
    elif r >= strategy[0] and r < strategy[0] + strategy[1]:
        return 1
    elif r >= strategy[0] + strategy[1] and r < sum(strategy):
        return 2
    else:
        return 0

# %%
def getScore(p1_action, p2_action):
    if p1_action == p2_action:
        return 'draw'
    elif p1_action == 0 and p2_action == 1:
        return 'p2 wins'
    elif p1_action == 0 and p2_action == 2:
        return 'p1 wins'
    elif p1_action == 1 and p2_action == 0:
        return 'p1 wins'
    elif p1_action == 1 and p2_action == 2:
        return 'p2 wins'
    elif p1_action == 2 and p2_action == 0:
        return 'p2 wins'
    elif p1_action == 2 and p2_action == 1:
        return 'p1 wins'

# %%
def train(iterations,p1_regretSum, p2_regretSum):
    ''' 
    Define each variable and give example values:
    - regretSum = [-2, -5, 2] ---> cumulative regret
    - oppStrategy = [0.3, 0.4, 0.3]
    - strategy = [0.3333333333333333, 0.3333333333333333, 0.3333333333333333] or [0.0, 0.0, 1.0] or [0.3, 0.4, 0.3] ---> policy yielded by regret matching for next RPS showdown
    - strategySum = [1.0, 0.3333333333333333, 3.6666666666666665] ---> sum of probabilities in strategy array over all iterations
    - myaction = 0, 1 or 2 ---> 'ROCK' 'PAPER' or 'SCISSORS'
    - otherAction = 0, 1 or 2 ---> 'ROCK' 'PAPER' or 'SCISSORS'
    - actionUtility = [-1, 1, -1] or [-1, 0, 1] ---> Hapiness you would have gotten from each of RPS had you chosen them against a fixed opponent choice like 'ROCK'. 
                      First the 3 actionUtilities are calculated for the opponent, then the action utility for myaction and opponent action pair is calculated. 
                      Then they're all used to get the regret and then regretSum
    '''
    p1_actionUtility = [0,0,0]
    p1_strategySum = [0,0,0]
    p2_actionUtility = [0,0,0]
    p2_strategySum = [0,0,0]
    actions = 3
    p1_wins_counter = 0
    p2_wins_counter = 0
    for i in range(0,iterations):
        ##Retrieve Actions
        p1_t = getStrategy(p1_regretSum,p1_strategySum)
        p1_strategy = [0.9, 0.05, 0.05] # <p1_t[0]-------------------------------------------------------------------------change to fixed or variable
        p1_strategySum = p1_t[1]
        p1_action = getAction(p1_strategy)
        #Define an arbitrary opponent strategy from which to adjust
        p2_t = getStrategy(p2_regretSum,p2_strategySum)
        p2_strategy = p2_t[0]
        p2_strategySum = p2_t[1]        
        p2_action = getAction(p2_strategy) 
        score = getScore(p1_action, p2_action)
        if score == 'p1 wins':  
            p1_wins_counter += 1  
        else: 
            p1_wins_counter += 0
        if score == 'p2 wins':  
            p2_wins_counter += 1  
        else: 
            p2_wins_counter += 0
        print('p1_strategy: ', p1_strategy, 'p2_strategy: ', p2_strategy)
        print('p1_regretSum: ', p1_regretSum, 'p2_regretSum: ', p2_regretSum)
        print('p1 chose: ', p1_action, 'p2 chose: ', p2_action)
        print(score)
        print('p1_wins_counter: ', p1_wins_counter, 'p2_wins_counter: ', p2_wins_counter)

        #Opponent Chooses scissors
        if p2_action == actions - 1: # FALSE: 3-1 = 2, WE HAVE otherAction == 1 
            #Utility(Rock) = 1
            p1_actionUtility[0] = 1
            #Utility(Paper) = -1
            p1_actionUtility[1] = -1
        #Opponent Chooses Rock
        elif p2_action == 0: # FALSE: WE HAVE otherAction == 1 
            #Utility(Scissors) = -1
            p1_actionUtility[actions - 1] = -1
            #Utility(Paper) = 1
            p1_actionUtility[1] = 1
        #Opopnent Chooses Paper
        else: # TRUE: WE HAVE otherAction == 1 
            #Utility(Rock) = -1
            p1_actionUtility[0] = -1
            #Utility(Scissors) = 1
            p1_actionUtility[2] = 1

        #Opponent Chooses scissors
        if p1_action == actions - 1: # FALSE: 3-1 = 2, WE HAVE otherAction == 1 
            #Utility(Rock) = 1
            p2_actionUtility[0] = 1
            #Utility(Paper) = -1
            p2_actionUtility[1] = -1
        #Opponent Chooses Rock
        elif p1_action == 0: # FALSE: WE HAVE otherAction == 1 
            #Utility(Scissors) = -1
            p2_actionUtility[actions - 1] = -1
            #Utility(Paper) = 1
            p2_actionUtility[1] = 1
        #Opopnent Chooses Paper
        else: # TRUE: WE HAVE otherAction == 1 
            #Utility(Rock) = -1
            p2_actionUtility[0] = -1
            #Utility(Scissors) = 1
            p2_actionUtility[2] = 1
                    
        #Add the regrets from this decision
        for i in range(0,actions):
            p1_regretSum[i] += p1_actionUtility[i] - p1_actionUtility[p1_action]
            p2_regretSum[i] += p2_actionUtility[i] - p2_actionUtility[p2_action]

    return p1_strategySum, p2_strategySum

# %%
def getAverageStrategy(iterations):
    ''' 
    Define each variable and give example values:
    - avgStrategy = [0, 0, 0] ---> a.k.a.: 'Maximally Exploitative Strategy' ---> Strategy to use in next round, considering info from all previous rounds put together
    - strategySum = [1.0, 0.3333333333333333, 3.6666666666666665] ---> sum of probabilities in strategy array over all iterations
    - oppStrategy = [0.3, 0.4, 0.3]
    - normalizingSum = 37 ---> used to get strategy array probabilities ---> strategy[i] = strategy[i]/normalizingSum ---> sum of positive regrets only
    '''
    actions = 3
    p1_strategySum, p2_strategySum = train(iterations, [0,0,0], [0,0,0])
    p1_avgStrategy = [0,0,0]
    p2_avgStrategy = [0,0,0]
    p1_normalizingSum = 0
    p2_normalizingSum = 0 
    for i in range(0,actions):
        p1_normalizingSum += p1_strategySum[i]
        p2_normalizingSum += p2_strategySum[i]
    for i in range(0,actions):
        if p1_normalizingSum > 0:
            p1_avgStrategy[i] = p1_strategySum[i] / p1_normalizingSum
        else:
            p1_avgStrategy[i] = 1.0 / actions
        if p2_normalizingSum > 0:
            p2_avgStrategy[i] = p2_strategySum[i] / p2_normalizingSum
        else:
            p2_avgStrategy[i] = 1.0 / actions
    print('avgStrategy: ', p1_avgStrategy)
    print('avgStrategy: ', p2_avgStrategy)
    return p1_avgStrategy, p2_avgStrategy

# %%
print("Maximally Exploitative Strat", getAverageStrategy(500))
# Out:
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# p1_regretSum:  [0, 0, 0] p2_regretSum:  [0, 0, 0]
# p1 chose:  0 p2 chose:  2
# p1 wins
# p1_wins_counter:  1 p2_wins_counter:  0
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.3333333333333333, 0.6666666666666666, 0.0]
# p1_regretSum:  [0, -2, -1] p2_regretSum:  [1, 2, 0]
# p1 chose:  0 p2 chose:  0
# draw
# p1_wins_counter:  1 p2_wins_counter:  0
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.25, 0.75, 0.0]
# p1_regretSum:  [0, -2, -3] p2_regretSum:  [1, 3, -1]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  1
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [0, 0, -1] p2_regretSum:  [0, 3, -3]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  2
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [0, 2, 1] p2_regretSum:  [-1, 3, -5]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  3
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [0, 4, 3] p2_regretSum:  [-2, 3, -7]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  4
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [0, 6, 5] p2_regretSum:  [-3, 3, -9]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  5
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [0, 8, 7] p2_regretSum:  [-4, 3, -11]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  6
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [0, 10, 9] p2_regretSum:  [-5, 3, -13]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  1 p2_wins_counter:  6
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-2, 10, 9] p2_regretSum:  [-7, 3, -13]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  7
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-2, 12, 11] p2_regretSum:  [-9, 3, -15]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  8
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-2, 14, 13] p2_regretSum:  [-11, 3, -17]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  9
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-2, 16, 15] p2_regretSum:  [-13, 3, -19]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  1 p2_wins_counter:  9
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 16, 15] p2_regretSum:  [-15, 3, -19]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  10
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 18, 17] p2_regretSum:  [-17, 3, -21]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  11
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 20, 19] p2_regretSum:  [-19, 3, -23]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  12
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 22, 21] p2_regretSum:  [-21, 3, -25]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  13
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 24, 23] p2_regretSum:  [-23, 3, -27]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  14
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 26, 25] p2_regretSum:  [-25, 3, -29]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  15
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 28, 27] p2_regretSum:  [-27, 3, -31]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  16
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 30, 29] p2_regretSum:  [-29, 3, -33]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  1 p2_wins_counter:  17
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-4, 32, 31] p2_regretSum:  [-31, 3, -35]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  2 p2_wins_counter:  17
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 32, 31] p2_regretSum:  [-29, 3, -35]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  18
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 34, 33] p2_regretSum:  [-29, 3, -37]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  19
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 36, 35] p2_regretSum:  [-29, 3, -39]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  20
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 38, 37] p2_regretSum:  [-29, 3, -41]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  21
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 40, 39] p2_regretSum:  [-29, 3, -43]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  22
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 42, 41] p2_regretSum:  [-29, 3, -45]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  23
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 44, 43] p2_regretSum:  [-29, 3, -47]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  24
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 46, 45] p2_regretSum:  [-29, 3, -49]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  25
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 48, 47] p2_regretSum:  [-29, 3, -51]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  26
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 50, 49] p2_regretSum:  [-29, 3, -53]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  27
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-6, 52, 51] p2_regretSum:  [-29, 3, -55]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  2 p2_wins_counter:  27
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-8, 52, 51] p2_regretSum:  [-31, 3, -55]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  28
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-8, 54, 53] p2_regretSum:  [-33, 3, -57]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  2 p2_wins_counter:  28
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-10, 54, 53] p2_regretSum:  [-35, 3, -57]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  29
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-10, 56, 55] p2_regretSum:  [-37, 3, -59]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  30
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-10, 58, 57] p2_regretSum:  [-39, 3, -61]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  31
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-10, 60, 59] p2_regretSum:  [-41, 3, -63]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  2 p2_wins_counter:  32
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-10, 62, 61] p2_regretSum:  [-43, 3, -65]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  3 p2_wins_counter:  32
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 62, 61] p2_regretSum:  [-41, 3, -65]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  33
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 64, 63] p2_regretSum:  [-41, 3, -67]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  34
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 66, 65] p2_regretSum:  [-41, 3, -69]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  35
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 68, 67] p2_regretSum:  [-41, 3, -71]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  36
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 70, 69] p2_regretSum:  [-41, 3, -73]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  37
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 72, 71] p2_regretSum:  [-41, 3, -75]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  38
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 74, 73] p2_regretSum:  [-41, 3, -77]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  39
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 76, 75] p2_regretSum:  [-41, 3, -79]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  40
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 78, 77] p2_regretSum:  [-41, 3, -81]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  41
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-12, 80, 79] p2_regretSum:  [-41, 3, -83]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  3 p2_wins_counter:  41
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 80, 79] p2_regretSum:  [-43, 3, -83]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  42
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 82, 81] p2_regretSum:  [-45, 3, -85]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  43
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 84, 83] p2_regretSum:  [-47, 3, -87]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  44
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 86, 85] p2_regretSum:  [-49, 3, -89]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  45
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 88, 87] p2_regretSum:  [-51, 3, -91]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  46
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 90, 89] p2_regretSum:  [-53, 3, -93]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  47
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 92, 91] p2_regretSum:  [-55, 3, -95]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  48
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 94, 93] p2_regretSum:  [-57, 3, -97]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  3 p2_wins_counter:  49
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-14, 96, 95] p2_regretSum:  [-59, 3, -99]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  4 p2_wins_counter:  49
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-16, 96, 95] p2_regretSum:  [-57, 3, -99]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  4 p2_wins_counter:  50
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-16, 98, 97] p2_regretSum:  [-57, 3, -101]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  4 p2_wins_counter:  51
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-16, 100, 99] p2_regretSum:  [-57, 3, -103]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  4 p2_wins_counter:  52
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-16, 102, 101] p2_regretSum:  [-57, 3, -105]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  4 p2_wins_counter:  53
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-16, 104, 103] p2_regretSum:  [-57, 3, -107]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  5 p2_wins_counter:  53
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 104, 103] p2_regretSum:  [-55, 3, -107]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  54
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 106, 105] p2_regretSum:  [-55, 3, -109]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  55
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 108, 107] p2_regretSum:  [-55, 3, -111]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  56
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 110, 109] p2_regretSum:  [-55, 3, -113]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  57
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 112, 111] p2_regretSum:  [-55, 3, -115]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  58
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 114, 113] p2_regretSum:  [-55, 3, -117]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  59
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 116, 115] p2_regretSum:  [-55, 3, -119]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  60
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 118, 117] p2_regretSum:  [-55, 3, -121]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  61
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 120, 119] p2_regretSum:  [-55, 3, -123]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  62
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 122, 121] p2_regretSum:  [-55, 3, -125]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  63
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 124, 123] p2_regretSum:  [-55, 3, -127]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  64
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 126, 125] p2_regretSum:  [-55, 3, -129]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  65
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 128, 127] p2_regretSum:  [-55, 3, -131]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  66
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 130, 129] p2_regretSum:  [-55, 3, -133]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  67
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 132, 131] p2_regretSum:  [-55, 3, -135]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  68
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 134, 133] p2_regretSum:  [-55, 3, -137]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  69
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 136, 135] p2_regretSum:  [-55, 3, -139]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  70
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 138, 137] p2_regretSum:  [-55, 3, -141]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  71
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 140, 139] p2_regretSum:  [-55, 3, -143]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  72
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 142, 141] p2_regretSum:  [-55, 3, -145]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  73
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 144, 143] p2_regretSum:  [-55, 3, -147]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  74
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 146, 145] p2_regretSum:  [-55, 3, -149]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  75
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 148, 147] p2_regretSum:  [-55, 3, -151]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  76
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 150, 149] p2_regretSum:  [-55, 3, -153]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  77
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 152, 151] p2_regretSum:  [-55, 3, -155]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  78
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 154, 153] p2_regretSum:  [-55, 3, -157]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  79
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 156, 155] p2_regretSum:  [-55, 3, -159]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  80
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 158, 157] p2_regretSum:  [-55, 3, -161]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  81
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 160, 159] p2_regretSum:  [-55, 3, -163]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  5 p2_wins_counter:  82
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-18, 162, 161] p2_regretSum:  [-55, 3, -165]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  6 p2_wins_counter:  82
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 162, 161] p2_regretSum:  [-53, 3, -165]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  83
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 164, 163] p2_regretSum:  [-53, 3, -167]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  84
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 166, 165] p2_regretSum:  [-53, 3, -169]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  85
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 168, 167] p2_regretSum:  [-53, 3, -171]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  86
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 170, 169] p2_regretSum:  [-53, 3, -173]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  87
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 172, 171] p2_regretSum:  [-53, 3, -175]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  88
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 174, 173] p2_regretSum:  [-53, 3, -177]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  89
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 176, 175] p2_regretSum:  [-53, 3, -179]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  90
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 178, 177] p2_regretSum:  [-53, 3, -181]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  91
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 180, 179] p2_regretSum:  [-53, 3, -183]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  6 p2_wins_counter:  92
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-20, 182, 181] p2_regretSum:  [-53, 3, -185]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  7 p2_wins_counter:  92
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-22, 182, 181] p2_regretSum:  [-51, 3, -185]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  7 p2_wins_counter:  93
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-22, 184, 183] p2_regretSum:  [-51, 3, -187]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  7 p2_wins_counter:  94
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-22, 186, 185] p2_regretSum:  [-51, 3, -189]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  7 p2_wins_counter:  95
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-22, 188, 187] p2_regretSum:  [-51, 3, -191]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  8 p2_wins_counter:  95
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-24, 188, 187] p2_regretSum:  [-49, 3, -191]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  96
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-24, 190, 189] p2_regretSum:  [-49, 3, -193]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  8 p2_wins_counter:  96
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 190, 189] p2_regretSum:  [-51, 3, -193]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  97
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 192, 191] p2_regretSum:  [-53, 3, -195]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  98
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 194, 193] p2_regretSum:  [-55, 3, -197]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  99
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 196, 195] p2_regretSum:  [-57, 3, -199]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  100
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 198, 197] p2_regretSum:  [-59, 3, -201]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  101
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 200, 199] p2_regretSum:  [-61, 3, -203]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  102
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 202, 201] p2_regretSum:  [-63, 3, -205]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  103
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 204, 203] p2_regretSum:  [-65, 3, -207]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  104
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 206, 205] p2_regretSum:  [-67, 3, -209]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  105
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 208, 207] p2_regretSum:  [-69, 3, -211]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  106
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 210, 209] p2_regretSum:  [-71, 3, -213]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  107
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 212, 211] p2_regretSum:  [-73, 3, -215]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  108
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 214, 213] p2_regretSum:  [-75, 3, -217]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  109
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 216, 215] p2_regretSum:  [-77, 3, -219]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  110
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 218, 217] p2_regretSum:  [-79, 3, -221]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  111
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 220, 219] p2_regretSum:  [-81, 3, -223]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  112
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 222, 221] p2_regretSum:  [-83, 3, -225]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  113
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 224, 223] p2_regretSum:  [-85, 3, -227]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  114
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 226, 225] p2_regretSum:  [-87, 3, -229]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  115
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 228, 227] p2_regretSum:  [-89, 3, -231]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  116
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 230, 229] p2_regretSum:  [-91, 3, -233]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  117
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 232, 231] p2_regretSum:  [-93, 3, -235]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  8 p2_wins_counter:  118
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-26, 234, 233] p2_regretSum:  [-95, 3, -237]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  9 p2_wins_counter:  118
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-28, 234, 233] p2_regretSum:  [-93, 3, -237]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  9 p2_wins_counter:  119
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-28, 236, 235] p2_regretSum:  [-93, 3, -239]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  9 p2_wins_counter:  120
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-28, 238, 237] p2_regretSum:  [-93, 3, -241]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  9 p2_wins_counter:  121
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-28, 240, 239] p2_regretSum:  [-93, 3, -243]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  9 p2_wins_counter:  122
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-28, 242, 241] p2_regretSum:  [-93, 3, -245]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  10 p2_wins_counter:  122
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 242, 241] p2_regretSum:  [-91, 3, -245]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  123
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 244, 243] p2_regretSum:  [-91, 3, -247]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  124
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 246, 245] p2_regretSum:  [-91, 3, -249]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  125
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 248, 247] p2_regretSum:  [-91, 3, -251]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  126
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 250, 249] p2_regretSum:  [-91, 3, -253]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  127
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 252, 251] p2_regretSum:  [-91, 3, -255]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  128
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 254, 253] p2_regretSum:  [-91, 3, -257]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  129
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 256, 255] p2_regretSum:  [-91, 3, -259]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  130
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 258, 257] p2_regretSum:  [-91, 3, -261]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  131
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 260, 259] p2_regretSum:  [-91, 3, -263]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  132
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 262, 261] p2_regretSum:  [-91, 3, -265]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  133
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 264, 263] p2_regretSum:  [-91, 3, -267]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  134
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 266, 265] p2_regretSum:  [-91, 3, -269]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  135
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 268, 267] p2_regretSum:  [-91, 3, -271]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  136
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 270, 269] p2_regretSum:  [-91, 3, -273]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  137
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 272, 271] p2_regretSum:  [-91, 3, -275]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  138
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 274, 273] p2_regretSum:  [-91, 3, -277]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  139
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 276, 275] p2_regretSum:  [-91, 3, -279]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  140
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-30, 278, 277] p2_regretSum:  [-91, 3, -281]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  10 p2_wins_counter:  140
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 278, 277] p2_regretSum:  [-93, 3, -281]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  141
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 280, 279] p2_regretSum:  [-95, 3, -283]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  142
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 282, 281] p2_regretSum:  [-97, 3, -285]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  143
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 284, 283] p2_regretSum:  [-99, 3, -287]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  144
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 286, 285] p2_regretSum:  [-101, 3, -289]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  145
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 288, 287] p2_regretSum:  [-103, 3, -291]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  146
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 290, 289] p2_regretSum:  [-105, 3, -293]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  147
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 292, 291] p2_regretSum:  [-107, 3, -295]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  148
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 294, 293] p2_regretSum:  [-109, 3, -297]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  149
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 296, 295] p2_regretSum:  [-111, 3, -299]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  150
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 298, 297] p2_regretSum:  [-113, 3, -301]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  151
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 300, 299] p2_regretSum:  [-115, 3, -303]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  152
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 302, 301] p2_regretSum:  [-117, 3, -305]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  153
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-32, 304, 303] p2_regretSum:  [-119, 3, -307]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  10 p2_wins_counter:  153
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-34, 304, 303] p2_regretSum:  [-121, 3, -307]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  154
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-34, 306, 305] p2_regretSum:  [-123, 3, -309]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  155
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-34, 308, 307] p2_regretSum:  [-125, 3, -311]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  156
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-34, 310, 309] p2_regretSum:  [-127, 3, -313]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  10 p2_wins_counter:  156
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 310, 309] p2_regretSum:  [-129, 3, -313]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  157
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 312, 311] p2_regretSum:  [-131, 3, -315]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  158
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 314, 313] p2_regretSum:  [-133, 3, -317]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  159
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 316, 315] p2_regretSum:  [-135, 3, -319]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  160
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 318, 317] p2_regretSum:  [-137, 3, -321]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  161
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 320, 319] p2_regretSum:  [-139, 3, -323]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  162
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 322, 321] p2_regretSum:  [-141, 3, -325]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  163
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 324, 323] p2_regretSum:  [-143, 3, -327]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  164
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 326, 325] p2_regretSum:  [-145, 3, -329]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  165
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 328, 327] p2_regretSum:  [-147, 3, -331]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  166
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 330, 329] p2_regretSum:  [-149, 3, -333]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  167
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 332, 331] p2_regretSum:  [-151, 3, -335]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  168
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 334, 333] p2_regretSum:  [-153, 3, -337]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  169
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 336, 335] p2_regretSum:  [-155, 3, -339]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  170
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 338, 337] p2_regretSum:  [-157, 3, -341]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  171
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 340, 339] p2_regretSum:  [-159, 3, -343]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  172
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 342, 341] p2_regretSum:  [-161, 3, -345]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  173
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 344, 343] p2_regretSum:  [-163, 3, -347]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  174
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 346, 345] p2_regretSum:  [-165, 3, -349]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  175
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 348, 347] p2_regretSum:  [-167, 3, -351]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  176
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 350, 349] p2_regretSum:  [-169, 3, -353]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  177
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 352, 351] p2_regretSum:  [-171, 3, -355]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  178
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 354, 353] p2_regretSum:  [-173, 3, -357]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  179
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 356, 355] p2_regretSum:  [-175, 3, -359]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  180
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 358, 357] p2_regretSum:  [-177, 3, -361]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  181
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 360, 359] p2_regretSum:  [-179, 3, -363]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  182
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 362, 361] p2_regretSum:  [-181, 3, -365]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  183
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 364, 363] p2_regretSum:  [-183, 3, -367]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  184
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 366, 365] p2_regretSum:  [-185, 3, -369]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  185
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 368, 367] p2_regretSum:  [-187, 3, -371]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  186
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 370, 369] p2_regretSum:  [-189, 3, -373]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  187
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-36, 372, 371] p2_regretSum:  [-191, 3, -375]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  10 p2_wins_counter:  187
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-38, 372, 371] p2_regretSum:  [-193, 3, -375]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  188
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-38, 374, 373] p2_regretSum:  [-195, 3, -377]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  10 p2_wins_counter:  189
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-38, 376, 375] p2_regretSum:  [-197, 3, -379]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  11 p2_wins_counter:  189
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-40, 376, 375] p2_regretSum:  [-195, 3, -379]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  11 p2_wins_counter:  190
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-40, 378, 377] p2_regretSum:  [-195, 3, -381]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  11 p2_wins_counter:  191
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-40, 380, 379] p2_regretSum:  [-195, 3, -383]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  12 p2_wins_counter:  191
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 380, 379] p2_regretSum:  [-193, 3, -383]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  192
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 382, 381] p2_regretSum:  [-193, 3, -385]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  193
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 384, 383] p2_regretSum:  [-193, 3, -387]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  194
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 386, 385] p2_regretSum:  [-193, 3, -389]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  195
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 388, 387] p2_regretSum:  [-193, 3, -391]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  196
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 390, 389] p2_regretSum:  [-193, 3, -393]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  197
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 392, 391] p2_regretSum:  [-193, 3, -395]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  198
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 394, 393] p2_regretSum:  [-193, 3, -397]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  199
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 396, 395] p2_regretSum:  [-193, 3, -399]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  200
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 398, 397] p2_regretSum:  [-193, 3, -401]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  12 p2_wins_counter:  201
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-42, 400, 399] p2_regretSum:  [-193, 3, -403]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  13 p2_wins_counter:  201
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-44, 400, 399] p2_regretSum:  [-191, 3, -403]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  202
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-44, 402, 401] p2_regretSum:  [-191, 3, -405]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  203
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-44, 404, 403] p2_regretSum:  [-191, 3, -407]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  204
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-44, 406, 405] p2_regretSum:  [-191, 3, -409]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  205
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-44, 408, 407] p2_regretSum:  [-191, 3, -411]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  206
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-44, 410, 409] p2_regretSum:  [-191, 3, -413]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  207
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-44, 412, 411] p2_regretSum:  [-191, 3, -415]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  13 p2_wins_counter:  207
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 412, 411] p2_regretSum:  [-193, 3, -415]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  208
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 414, 413] p2_regretSum:  [-195, 3, -417]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  209
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 416, 415] p2_regretSum:  [-197, 3, -419]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  210
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 418, 417] p2_regretSum:  [-199, 3, -421]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  211
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 420, 419] p2_regretSum:  [-201, 3, -423]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  212
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 422, 421] p2_regretSum:  [-203, 3, -425]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  213
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 424, 423] p2_regretSum:  [-205, 3, -427]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  214
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 426, 425] p2_regretSum:  [-207, 3, -429]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  215
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 428, 427] p2_regretSum:  [-209, 3, -431]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  216
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-46, 430, 429] p2_regretSum:  [-211, 3, -433]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  13 p2_wins_counter:  217
# ...
# p1_regretSum:  [-94, 744, 743] p2_regretSum:  [-241, 3, -745]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  374
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-94, 746, 745] p2_regretSum:  [-243, 3, -747]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  375
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-94, 748, 747] p2_regretSum:  [-245, 3, -749]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  376
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-94, 750, 749] p2_regretSum:  [-247, 3, -751]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  377
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-94, 752, 751] p2_regretSum:  [-249, 3, -753]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  378
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-94, 754, 753] p2_regretSum:  [-251, 3, -755]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  379
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-94, 756, 755] p2_regretSum:  [-253, 3, -757]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  27 p2_wins_counter:  379
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-96, 756, 755] p2_regretSum:  [-255, 3, -757]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  380
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-96, 758, 757] p2_regretSum:  [-257, 3, -759]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  27 p2_wins_counter:  381
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-96, 760, 759] p2_regretSum:  [-259, 3, -761]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  28 p2_wins_counter:  381
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-98, 760, 759] p2_regretSum:  [-257, 3, -761]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  28 p2_wins_counter:  382
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-98, 762, 761] p2_regretSum:  [-257, 3, -763]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  29 p2_wins_counter:  382
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 762, 761] p2_regretSum:  [-255, 3, -763]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  383
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 764, 763] p2_regretSum:  [-255, 3, -765]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  384
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 766, 765] p2_regretSum:  [-255, 3, -767]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  385
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 768, 767] p2_regretSum:  [-255, 3, -769]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  386
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 770, 769] p2_regretSum:  [-255, 3, -771]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  387
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 772, 771] p2_regretSum:  [-255, 3, -773]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  388
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 774, 773] p2_regretSum:  [-255, 3, -775]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  389
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 776, 775] p2_regretSum:  [-255, 3, -777]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  390
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 778, 777] p2_regretSum:  [-255, 3, -779]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  391
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 780, 779] p2_regretSum:  [-255, 3, -781]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  392
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 782, 781] p2_regretSum:  [-255, 3, -783]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  393
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 784, 783] p2_regretSum:  [-255, 3, -785]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  394
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 786, 785] p2_regretSum:  [-255, 3, -787]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  395
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 788, 787] p2_regretSum:  [-255, 3, -789]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  396
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 790, 789] p2_regretSum:  [-255, 3, -791]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  397
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 792, 791] p2_regretSum:  [-255, 3, -793]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  398
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 794, 793] p2_regretSum:  [-255, 3, -795]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  399
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 796, 795] p2_regretSum:  [-255, 3, -797]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  29 p2_wins_counter:  400
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-100, 798, 797] p2_regretSum:  [-255, 3, -799]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  30 p2_wins_counter:  400
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 798, 797] p2_regretSum:  [-253, 3, -799]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  401
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 800, 799] p2_regretSum:  [-253, 3, -801]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  402
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 802, 801] p2_regretSum:  [-253, 3, -803]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  403
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 804, 803] p2_regretSum:  [-253, 3, -805]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  404
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 806, 805] p2_regretSum:  [-253, 3, -807]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  405
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 808, 807] p2_regretSum:  [-253, 3, -809]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  406
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 810, 809] p2_regretSum:  [-253, 3, -811]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  407
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 812, 811] p2_regretSum:  [-253, 3, -813]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  408
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 814, 813] p2_regretSum:  [-253, 3, -815]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  409
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 816, 815] p2_regretSum:  [-253, 3, -817]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  410
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 818, 817] p2_regretSum:  [-253, 3, -819]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  411
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 820, 819] p2_regretSum:  [-253, 3, -821]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  412
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 822, 821] p2_regretSum:  [-253, 3, -823]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  30 p2_wins_counter:  413
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-102, 824, 823] p2_regretSum:  [-253, 3, -825]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  31 p2_wins_counter:  413
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-104, 824, 823] p2_regretSum:  [-251, 3, -825]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  31 p2_wins_counter:  414
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-104, 826, 825] p2_regretSum:  [-251, 3, -827]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  32 p2_wins_counter:  414
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 826, 825] p2_regretSum:  [-249, 3, -827]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  32 p2_wins_counter:  415
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 828, 827] p2_regretSum:  [-249, 3, -829]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  32 p2_wins_counter:  416
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 830, 829] p2_regretSum:  [-249, 3, -831]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  32 p2_wins_counter:  417
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 832, 831] p2_regretSum:  [-249, 3, -833]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  32 p2_wins_counter:  418
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 834, 833] p2_regretSum:  [-249, 3, -835]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  32 p2_wins_counter:  419
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 836, 835] p2_regretSum:  [-249, 3, -837]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  32 p2_wins_counter:  420
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 838, 837] p2_regretSum:  [-249, 3, -839]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  32 p2_wins_counter:  421
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-106, 840, 839] p2_regretSum:  [-249, 3, -841]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  33 p2_wins_counter:  421
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 840, 839] p2_regretSum:  [-247, 3, -841]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  422
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 842, 841] p2_regretSum:  [-247, 3, -843]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  423
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 844, 843] p2_regretSum:  [-247, 3, -845]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  424
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 846, 845] p2_regretSum:  [-247, 3, -847]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  425
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 848, 847] p2_regretSum:  [-247, 3, -849]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  426
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 850, 849] p2_regretSum:  [-247, 3, -851]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  427
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 852, 851] p2_regretSum:  [-247, 3, -853]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  428
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 854, 853] p2_regretSum:  [-247, 3, -855]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  429
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 856, 855] p2_regretSum:  [-247, 3, -857]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  430
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 858, 857] p2_regretSum:  [-247, 3, -859]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  431
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 860, 859] p2_regretSum:  [-247, 3, -861]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  33 p2_wins_counter:  432
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-108, 862, 861] p2_regretSum:  [-247, 3, -863]
# p1 chose:  1 p2 chose:  1
# draw
# p1_wins_counter:  33 p2_wins_counter:  432
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-110, 862, 861] p2_regretSum:  [-249, 3, -863]
# p1 chose:  2 p2 chose:  1
# p1 wins
# p1_wins_counter:  34 p2_wins_counter:  432
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 862, 861] p2_regretSum:  [-247, 3, -861]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  433
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 864, 863] p2_regretSum:  [-247, 3, -863]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  434
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 866, 865] p2_regretSum:  [-247, 3, -865]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  435
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 868, 867] p2_regretSum:  [-247, 3, -867]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  436
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 870, 869] p2_regretSum:  [-247, 3, -869]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  437
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 872, 871] p2_regretSum:  [-247, 3, -871]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  438
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 874, 873] p2_regretSum:  [-247, 3, -873]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  439
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 876, 875] p2_regretSum:  [-247, 3, -875]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  440
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 878, 877] p2_regretSum:  [-247, 3, -877]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  441
# p1_strategy:  [0.9, 0.05, 0.05] p2_strategy:  [0.0, 1.0, 0.0]
# p1_regretSum:  [-112, 880, 879] p2_regretSum:  [-247, 3, -879]
# p1 chose:  0 p2 chose:  1
# p2 wins
# p1_wins_counter:  34 p2_wins_counter:  442
# avgStrategy:  [0.0026666666666666666, 0.5006576473685947, 0.49667568596473854]
# avgStrategy:  [0.0018333333333333333, 0.9975, 0.0006666666666666666]
# Maximally Exploitative Strat ([0.0026666666666666666, 0.5006576473685947, 0.49667568596473854], [0.0018333333333333333, 0.9975, 0.0006666666666666666])
